# %%
# %load_ext autoreload
# %autoreload 2

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
# %matplotlib inline

# %%
car_bottom = cv2.imread("../data/car_bottom/car_bottom1.jpg")
bomb = cv2.imread("../data/bombs/c4_csgo.webp")

# %%
car_bottom = cv2.cvtColor(car_bottom, cv2.COLOR_BGR2RGB)
bomb = cv2.cvtColor(bomb, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(car_bottom)

# %%
plt.imshow(bomb)

# %%
car_bottom.shape, bomb.shape
# Out:
# ((904, 2599, 3), (435, 323, 3))

# %%
bomb_resized = cv2.resize(bomb, (40, 50))

# %%
car_resized = cv2.resize(car_bottom, (640, 640))

# %% [markdown]
# ---

# %%
from generate_data import shift_image, get_object_mask, generate_data
from frame_converter import FrameConverter

# %%
plt.imshow(
    generate_data(car_resized, bomb_resized)
)

# %%
frames = []
for i in range(50):
    frames.append(generate_data(car_resized, bomb_resized))

# %%
plt.imshow(frames[30])

# %%
converter = FrameConverter("freq", epsilon=100)

# %%
frames_converted = converter.convert_frames(frames, compute_window=2)

# %%
plt.figure(figsize=(16, 9))
plt.imshow(frames_converted[33])
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
